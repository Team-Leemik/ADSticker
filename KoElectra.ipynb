# %%
import torch

# %%
from transformers import ElectraTokenizer, ElectraForSequenceClassification

model_name = "monologg/koelectra-v3-small-nsmc"
tokenizer = ElectraTokenizer.from_pretrained(model_name)
model = ElectraForSequenceClassification.from_pretrained(model_name)

# %%
device = torch.device("cuda")
model.to(device)
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(35000, 128, padding_idx=0)
#       (position_embeddings): Embedding(512, 128)
#       (token_type_embeddings): Embedding(2, 128)
#       (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (embeddings_project): Linear(in_features=128, out_features=256, bias=True)
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=256, out_features=256, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
wordsToRemove = ['광고', '협찬']

# %%
def filterWords(text) :
    for word in wordsToRemove:
        text = text.replace(word, '')
    return text

# %%
def sentimentalAnalysis(text):
    with torch.no_grad():
        encodedInput = tokenizer.encode_plus(filterWords(text), return_tensors="pt").to(device)
        output = model(encodedInput['input_ids'], attention_mask = encodedInput['attention_mask'])
        logits = output.logits
        probabilities = torch.softmax(logits, dim=1)
        #predictedLabel = torch.argmax(probabilities, dim=1)
        return probabilities[0][1].item()

# %%
from flask import Flask, request, jsonify
import threading 
import logging
import json
from werkzeug.serving import run_simple
app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    try:
        data = request.get_json(force=True)
        print(data)
        result = sentimentalAnalysis(data)
        return jsonify(result)
    except Exception as e:
        app.logger.error('Error occured at predict(): %s', e)
        return jsonify('-1'), 500

class FlaskThread(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.daemon = True
        self.srv = None
        self.ctx = app.test_request_context()
        self.ctx.push()

    def run(self):
        self.srv = run_simple('0.0.0.0', 5000, app, use_debugger=True, use_reloader=False)
        
    def shutdown(self):
        if self.srv is not None:
            self.srv.shutdown()

flaskThread = FlaskThread()
flaskThread.start()

input("Press Enter to stop the Flask app...")
flaskThread.shutdown()
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://163.239.26.24:5000
# Press CTRL+C to quit
# 도윤이 진짜 좋은 의사될거같다
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 규민이 귀엽네요 ~
# 이말년이 개잘하네<br>ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 맑다. 오염되지않은.
# 도윤앙 훌륭해져~~
# 두친구 모두 참 반듯하네 ㅎ
# 와 도윤이 대박,, 저런 아들 낳고싶네
# 역시 꼴찌 인생은 그냥저냥 사는구만ㅋㅋㅋ
# 도윤이 너무 좋다
# 수방사네 ㄷㄷㄷ
# 저러니 사랑이 쌓이지
# 규민씨 피부 왤케 좋아
# 규민씨는 사람을 행복하게 해주는 밝은 사람이네.
# 이쁘다
# 꼭 소명감있는 내과 외과 전문의가 되어주세요 피안성.. ㄴㄴㄴ
# 와 근데 그림은 진짜 대박이다 .. 타고난 재능
# 도윤님은 정말 따뜻한 좋은의사가 될것같네요~ 규민님은 훌륭한 미술재능이 있으니 꼭 잘 살려보시길 바래요~ 두분 너무 건강하고 바르게 잘 성장하신거같아 너무 기쁘네요~
# 귀엽자 귀여웡ㅇㅇㅇ 둘다 행복하길 바래요~
# 두 친구 우정 오래 오래 갔으면 좋겠네요.   건강하게 잘 자라신거 같아요.
# 화이팅!!!!!
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 도윤님 곰돌이 푸같아여 ㅋㅋㅋㅋㅋㅋㅋ
# 의사 되고 ㅡ.저 그림으로 국연수 상태 고요 처럼 일러스트 웹툰 작가 상 그림은 아니고 미대나 어디쪽 안 간 느낌이라 아쉽네요 . 우리나란 10대에 열심히 살아야 더 편한 나라라고됴 롹실히
# 두분중에 한명이 이성이였다면 ㅋㅋ결혼도 사알짝생각해볼수있는 조합
# 둘다 넘 매력있어요~~^^<br>마치 도윤씨는 제남편 규민씨는 저를 보는듯한 느낌이드는건 왜일까요?  ㅎㅎ
# 규민아 탈모 힘내...
# 도윤님 인상이 너무 좋네
# 둘다 넘 기엽다ㅋㅋ
# 도윤이 딱 느낌이 내관데...ㅋㅋㅋㅋㅋㅋㅋ
# 목사같아
# 도윤이... 인터뷰 미쳤다 진짜 어떻게 애가 저러지 공부 겁나 잘하는데 저렇게 겸손한 사람 태어나서 첨 봐
# 나보다 1살 어리구나
# ㄱㅇㅇ
# 똑똑하고 잘났는데 겸손하고 예의도 바름. 말 하는데서 나오는 저 자신감과 당당함이 멋있어보이네요.
# <a href="https://www.youtube.com/watch?v=uETZGq0-FHU&amp;t=7m51s">7:51</a> 죵나웃기넼ㅋㅋㅋㅋ
# 둘다 순수하고 인상좋고 긔여웤ㅋㅋㅋㅋ
# <a href="https://www.youtube.com/watch?v=uETZGq0-FHU&amp;t=3m58s">3:58</a> ㅋㅋㅋㅋㅋㅋ도윤샘 T에요?ㅋㅋㅋㅋ
# 두분다 진짜 너무 맑게 자랐네요 입꼬리가 자동으로올라가네요
# 우리나라 미래가 밝다😊❤
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 요즘같은 세상에 규민씨는 보석이다
# 도윤님 약간 큰별쌤 느낌나요 ㅋㅋㅋㅋㅋㅋㅋ
# 👍👍
# 저사람은 의대생이고 옆분은 장교심?
# 둘다 너무 귀여우시고ㅋㅋ.. 예의바르심 !!
# 그냥 흐뭇하게 보다가… <a href="https://www.youtube.com/watch?v=uETZGq0-FHU&amp;t=13m21s">13:21</a> 왜 눈물 나지??
# 신경 정신과 잘 어울릴것 같음.<br>환자의 말을 잘 들어주고 마음을 잘 치료 하실것 같음
# 어떻게 말을 저렇게 이쁘게 하지 ㅠㅜㅠㅠ 자기 재능은 하나의 작은 재능이라 그러고 규민이 재능은 큰 재능이라 그러고 본인은 낮추고 남은 높이고 ㅠㅜㅠㅠㅠㅜㅠㅠ 징짜 인성 대박이다 ,,,, 멋있고 똑똑하거 스윗하고 다 해 도윤님~~~~
# 모두 유쾌해~~ <br>말년님은 ㅋㅋㅋ 너무 웃겨
# 아마 부모님들이 인성이 훌륭하신 분들일 거야.
# 규민씨 말하는 센스 대박!! 너무 웃겨요 😂😂
# 보물섬 김동현 부캐 폼 미쳤네
# ㅋㅋㅋㅋ100퍼센트 전역ㅋㅋㅋㅋㅋ
# 도윤이는 진짜 좋은의사가 될것같다 부모님이 참 잘 키워서 행복하시겠다
# 그때 보면서 재밌기도 하고 규민군에게는 부담되는 프로그램이겠다..싶은 생각도 들었는데 세월이 많이 흘렀네요 ㅎㅎ 도윤군은.. 따뜻한 의사가 되겠지요? ㅎㅎ 어릴때도 고개가 살짝 기울어져있는거같은데.. 안불편한지;;;;
# 사람은 변하지 않네요.
# 진짜 도윤씨는 공부잘하는 것도 대단한데 인성이 바르신게 더 대단한 것 같아요
# 도윤씨 왜 계속 목이. 꺾여계시나걱정됨
# 전에 가출도 하던 공부 안하던 친구를 잡아다가<br>매일 독서실에 끌구 다녔던 생각나네 ㅋㅋ<br>졸업할때 담임선생님이 엄청 고마워하셨느데 ㅋㅋㅋ
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 아니 23살 대학생이 교수님처럼 말을하네ㅋㅋㅋ둘다 귀여움
# 귀엽다 애들ㅋㅋㅋ
# 이뻐라.열시미공부하더니<br>의대생이됫구나
# 머리 엄청크네
# 조세호 이제 안 나오고 침착맨이 나옴?
# 약간 소아과 의사선생님 느낌 ㅋㅋㅋㅎㅎㅎ 아이들도 능숙하게 잘 다루실(?)것 같아요 ㅋㅋ
# 어쩜 말을 저렇게 이쁘게 할까요... 표정과 말투에 제가 배워야할 부분이 많네요 이쁘게 말하는 법에 대해 다시 한번 느끼게 됩니다.
# 와 본인 재능은 작다고 표현하고 상대방 재능은 크다고 표현하는구나 진짜 멋있다
# 뭔가 일타강사랑 흔한 학생때 우리모습 같은 투샷 ㅋㅋㅋㅋㅋㅋ 부장님과 팀원 ㅋㅋㅋㅋㅋㅋ
# 규민이가 더 똑똑하네. 도윤인 철 들은 것 같고.
# 재석님 말대로 얼굴만 보면 유재석님이 제일 의사관상인데ㅋㅋㅋ
# 공부를 열심히 해야 하는 이유<br>의대 vs 군대
# 규민 &amp; 도윤 정말 잘 컸네요... 그리고 말년씨 재밌어요.
# 반짝반짝 빛나는 두 분, 이렇게 보니 넘 반갑네용!!
# 아무생각없이  흐뭇해지네요~~
# 도윤씨 면접 개잘보겠다
# 도윤이는 본과3년이라 힘들텐데 건강하고 마음도 따뜻한 의사쌤이 될거라 믿어요😊
# 규민이 군대전역 잘하고 미술전공해서 미술학원 쌤되면 애들이 넘 좋아할듯😊
# 좋은 친구들이다<br>의사되면 진료받고 싶네^^
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 그동안 궁금했는데 이렇게 멋지게 다들 커서 다시보니 넘 반갑고 고마워요❤
# 규민 센스 짱이네요~
# 규민이 넘 긔요미
# 두분 다 다른 매력이 있네용!
# 성적은 차이 나지만, 그 외는 앞 서거니 딋 서거니 하는데......<br>택하라면 규민이를 쪽으로...... ㅎㅎ
# 흐뭇하게 잘 보고 갑니다! 두분 오래 오래 봤으면 좋겠네요
# 위트있고 착하고 겸손한 규민씨 매력터집니다 ㅎㅎ<br>누구보다 사명감 있는 의사를 꿈꾸는 도윤씨도 멋있구요~<br>두분 응원합니다!!
# 의사가 저렇게 1등정도 해야 되는줄 알았는데 F맞고 과락해도 의사가 되는 인간은 뭐냐
# 한분은 소아과의사샘하시고 한분은 소아과오시는 아이들에게 예쁜 캐리커쳐나 그림을 그려 주면 좋겠어요
# 둘다 스타일은 확다른데 말을 엄청 맛깔나게하네
# 예비 의사샘 교복입고 나온줄 알았네..😂
# 규민이 넘나 최웅같음 귀여우ㅓ요 ㅋㅋㅋㅋㅋ
# 타고난 모범생…좋은 의사가 되어주세용
# 꼴등과 1등은 한적이 없지만 등수는 상관이 없다<br>항상 즐기고 행복하게 사는게 낫다
# 성적으로 꼴지였지 삶 자체는 꼴지가 아녔음 또 어떻게 살아야 하는거가 중요
# ㅅㅂ ㅋㅋㅋㅋ 의사관상 개쩌네 ㅋㅋ
# 어짜피 <br><br>공부 잘하고 인사성 밝은 애들은 잘 살아(찐사회생활내공)<br><br>우리가 보듬어야 될 애들은 <br><br>학업성적 떨어지고 교우 관계가 원만하지 않은 애들이지 않나?<br><br>베스트 댓글 때문에  좀 화가 나서 몇자 적어<br><br>전교1등이 잘 못 했다는게 아니야!!<br><br>전교 꼴등도 부끄럽지 않게 <br><br>맡은바 사회적 역활을 잘 하며 <br><br>다 같이 잘 살아보자는게<br><br>2023년을 살아가는 우리들의<br><br><br><br><br>MZ세대를 살아 가는 우리들의<br><br>새로운  &quot;새마을 운동&quot; 같애
# 규민쓰 이말년한테 영광입니다 하는 센스와 매너 짱이네
# 7년이 지났는데 어떻게 머리스타일도 똑같애 ㅋㅋ
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:35:45] "POST /predict HTTP/1.1" 200 -
# 대박 이 두분도 나오셨구나 두 분 다 어렸을때랑 똑같이 크셨네ㅋㅋㅋㅋㅋㅋ
# 와 사람이 진짜 바르네..
# 도윤씨는 인상이 진짜좋다 ㅋㅋㅋㅋ 사람이 선해보임
# 규민씨 꿈을 응원합니다.😊
# 도윤 씨는 그 때나 지금이나 10년 차 과장님 같아 ㅋㅋ<br>이런 얼굴이 40 넘어도 계속 그대로 멈춰서 동안되던데
